# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnudas-1212/machine-learning-easy-algo/blob/main/penguin(all_classification_models).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/penguins_size.csv')

# %%
df
# Out:
#     species     island  ...  body_mass_g     sex
# 0    Adelie  Torgersen  ...       3750.0    MALE
# 1    Adelie  Torgersen  ...       3800.0  FEMALE
# 2    Adelie  Torgersen  ...       3250.0  FEMALE
# 3    Adelie  Torgersen  ...          NaN     NaN
# 4    Adelie  Torgersen  ...       3450.0  FEMALE
# ..      ...        ...  ...          ...     ...
# 339  Gentoo     Biscoe  ...          NaN     NaN
# 340  Gentoo     Biscoe  ...       4850.0  FEMALE
# 341  Gentoo     Biscoe  ...       5750.0    MALE
# 342  Gentoo     Biscoe  ...       5200.0  FEMALE
# 343  Gentoo     Biscoe  ...       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
df['culmen_depth_mm'].fillna(df['culmen_depth_mm'].mean(),inplace=True)
df['culmen_length_mm'].fillna(df['culmen_length_mm'].mean(),inplace=True)
df['flipper_length_mm'].fillna(df['flipper_length_mm'].mean(),inplace=True)
df['body_mass_g'].fillna(df['body_mass_g'].mean(),inplace=True)

# %%
df
# Out:
#     species     island  ...  body_mass_g     sex
# 0    Adelie  Torgersen  ...  3750.000000    MALE
# 1    Adelie  Torgersen  ...  3800.000000  FEMALE
# 2    Adelie  Torgersen  ...  3250.000000  FEMALE
# 3    Adelie  Torgersen  ...  4201.754386     NaN
# 4    Adelie  Torgersen  ...  3450.000000  FEMALE
# ..      ...        ...  ...          ...     ...
# 339  Gentoo     Biscoe  ...  4201.754386     NaN
# 340  Gentoo     Biscoe  ...  4850.000000  FEMALE
# 341  Gentoo     Biscoe  ...  5750.000000    MALE
# 342  Gentoo     Biscoe  ...  5200.000000  FEMALE
# 343  Gentoo     Biscoe  ...  5400.000000    MALE
#
# [344 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      0
# culmen_depth_mm       0
# flipper_length_mm     0
# body_mass_g           0
# sex                  10
# dtype: int64

# %%
df
# Out:
#     species     island  ...  body_mass_g     sex
# 0    Adelie  Torgersen  ...  3750.000000    MALE
# 1    Adelie  Torgersen  ...  3800.000000  FEMALE
# 2    Adelie  Torgersen  ...  3250.000000  FEMALE
# 3    Adelie  Torgersen  ...  4201.754386     NaN
# 4    Adelie  Torgersen  ...  3450.000000  FEMALE
# ..      ...        ...  ...          ...     ...
# 339  Gentoo     Biscoe  ...  4201.754386     NaN
# 340  Gentoo     Biscoe  ...  4850.000000  FEMALE
# 341  Gentoo     Biscoe  ...  5750.000000    MALE
# 342  Gentoo     Biscoe  ...  5200.000000  FEMALE
# 343  Gentoo     Biscoe  ...  5400.000000    MALE
#
# [344 rows x 7 columns]

# %%
df['sex'].fillna('MALE',inplace=True)

# %%
df
# Out:
#     species     island  ...  body_mass_g     sex
# 0    Adelie  Torgersen  ...  3750.000000    MALE
# 1    Adelie  Torgersen  ...  3800.000000  FEMALE
# 2    Adelie  Torgersen  ...  3250.000000  FEMALE
# 3    Adelie  Torgersen  ...  4201.754386    MALE
# 4    Adelie  Torgersen  ...  3450.000000  FEMALE
# ..      ...        ...  ...          ...     ...
# 339  Gentoo     Biscoe  ...  4201.754386    MALE
# 340  Gentoo     Biscoe  ...  4850.000000  FEMALE
# 341  Gentoo     Biscoe  ...  5750.000000    MALE
# 342  Gentoo     Biscoe  ...  5200.000000  FEMALE
# 343  Gentoo     Biscoe  ...  5400.000000    MALE
#
# [344 rows x 7 columns]

# %%
df['sex'].unique()
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)

# %%
df
# Out:
#     species     island  ...  body_mass_g     sex
# 0    Adelie  Torgersen  ...  3750.000000    MALE
# 1    Adelie  Torgersen  ...  3800.000000  FEMALE
# 2    Adelie  Torgersen  ...  3250.000000  FEMALE
# 3    Adelie  Torgersen  ...  4201.754386    MALE
# 4    Adelie  Torgersen  ...  3450.000000  FEMALE
# ..      ...        ...  ...          ...     ...
# 339  Gentoo     Biscoe  ...  4201.754386    MALE
# 340  Gentoo     Biscoe  ...  4850.000000  FEMALE
# 341  Gentoo     Biscoe  ...  5750.000000    MALE
# 342  Gentoo     Biscoe  ...  5200.000000  FEMALE
# 343  Gentoo     Biscoe  ...  5400.000000    MALE
#
# [344 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df=df.drop(336,axis=0)

# %%
df
# Out:
#     species     island  ...  body_mass_g     sex
# 0    Adelie  Torgersen  ...  3750.000000    MALE
# 1    Adelie  Torgersen  ...  3800.000000  FEMALE
# 2    Adelie  Torgersen  ...  3250.000000  FEMALE
# 3    Adelie  Torgersen  ...  4201.754386    MALE
# 4    Adelie  Torgersen  ...  3450.000000  FEMALE
# ..      ...        ...  ...          ...     ...
# 339  Gentoo     Biscoe  ...  4201.754386    MALE
# 340  Gentoo     Biscoe  ...  4850.000000  FEMALE
# 341  Gentoo     Biscoe  ...  5750.000000    MALE
# 342  Gentoo     Biscoe  ...  5200.000000  FEMALE
# 343  Gentoo     Biscoe  ...  5400.000000    MALE
#
# [343 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()

# %%
new_df=df.apply(label.fit_transform)

# %%
new_df
# Out:
#      species  island  culmen_length_mm  ...  flipper_length_mm  body_mass_g  sex
# 0          0       2                42  ...                  6           31    1
# 1          0       2                45  ...                 11           33    0
# 2          0       2                51  ...                 20           12    0
# 3          0       2                82  ...                 26           46    1
# 4          0       2                22  ...                 18           19    0
# ..       ...     ...               ...  ...                ...          ...  ...
# 339        2       0                82  ...                 26           46    1
# 340        2       0               106  ...                 40           67    0
# 341        2       0               137  ...                 47           88    1
# 342        2       0                90  ...                 37           77    0
# 343        2       0               132  ...                 38           81    1
#
# ...

# %%
x=new_df.iloc[:,:-1]
y=new_df.iloc[:,-1]

# %%
y
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 339    1
# 340    0
# 341    1
# 342    0
# 343    1
# Name: sex, Length: 343, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=20)

# %%
x_train.shape
# Out:
# (229, 6)

# %% [markdown]
# XGBOOST

# %%
from xgboost import XGBClassifier

# %%
model_xgb=XGBClassifier(n_estimatiors=8,max_depth=6,gamma=0.1,learning_rate=0.01)

# %%
model_xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0.1,
#               learning_rate=0.01, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=None, n_estimatiors=8,
#               n_estimators=100, n_jobs=1, nthread=None,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#               subsample=1, verbosity=1)

# %%
xgb_pred=model_xgb.predict(x_test)

# %%
accuracy_score(y_test,xgb_pred)
# Out:
# 0.9298245614035088

# %%
print(classification_report(y_test,xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.92        52
#            1       0.91      0.97      0.94        62
#
#     accuracy                           0.93       114
#    macro avg       0.93      0.93      0.93       114
# weighted avg       0.93      0.93      0.93       114

# %% [markdown]
# Random Tree Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf=RandomForestClassifier()

# %%
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy_score(y_test,rf_pred)
# Out:
# 0.8947368421052632

# %%
print(classification_report(y_test,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89        52
#            1       0.93      0.87      0.90        62
#
#     accuracy                           0.89       114
#    macro avg       0.89      0.90      0.89       114
# weighted avg       0.90      0.89      0.89       114

# %%
from sklearn import tree
fn=new_df.columns
fig,axes=plt.subplots(nrows=1,ncols=5,figsize=(10,6),dpi=900)
for index in range(0,5):
  tree.plot_tree(model_rf.estimators_[index],
                 feature_names=fn,
                 class_names=['yes','no'],
                 filled=True,
                 ax = axes[index]
                );


  axes[index].set_title('Estimator: ' + str(index), fontsize = 11)
fig.savefig('rf_5trees.png')

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_log=LogisticRegression()

# %%
model_log.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
log_pred=model.predict(x_test)

# %%
accuracy_score(y_test,log_pred)
# Out:
# 0.8947368421052632

# %%
print(classification_report(y_test,log_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89        52
#            1       0.93      0.87      0.90        62
#
#     accuracy                           0.89       114
#    macro avg       0.89      0.90      0.89       114
# weighted avg       0.90      0.89      0.89       114

# %% [markdown]
# Decesion Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_dt=DecisionTreeClassifier()

# %%
model_dt.fit(x_test,y_test)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
dt_pred=model.predict(x_test)

# %%
accuracy_score(y_test,dt_pred)
# Out:
# 0.8947368421052632

# %%
print(classification_report(y_test,dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89        52
#            1       0.93      0.87      0.90        62
#
#     accuracy                           0.89       114
#    macro avg       0.89      0.90      0.89       114
# weighted avg       0.90      0.89      0.89       114

# %%
from sklearn import tree
fig=plt.figure(figsize=(20,10))
_=tree.plot_tree(model3,feature_names=new_df.columns,class_names=['no','yes'],label='all',filled=True)

# %% [markdown]
# kNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn=KNeighborsClassifier()

# %%
model_knn.fit(x_test,y_test)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
Knn_pred=model_knn.predict(x_test)

# %%
accuracy_score(y_test,Knn_pred)
# Out:
# 0.9385964912280702

# %%
print(classification_report(y_test,Knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93        52
#            1       0.97      0.92      0.94        62
#
#     accuracy                           0.94       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.94      0.94      0.94       114

# %% [markdown]
# From all of the above models Knn has high accuracy
